# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('publication')

# %%
date = np.array([1946, 1965, 1968, 1976, 1982, 1985, 1997, 2001, 2002, 2005, 2012, 2013, 2016])
flops = np.array([5e2, 3e6, 9e6, 160e6, 800e6, 1.9e9, 2e12, 7e12, 36e12, 470e12, 16e15, 34e15, 93e15])
name = ['ENIAC', 'IBM 7030', 'CDC 6600', 'Cray-1', 'Cray X-MP', 'Cray-2', 'ASCI Red', 'ASCI White', 'Blue Gene/L', 'Titan', 'Sequoia', 'Tianhe-2', 'ST']
colors = ['#C5705D',            # Base color
    '#8B0000',        # Dark Red

    '#A52A2A',        # Brown

    '#B22222',        # Firebrick

    '#800000',        # Maroon

    '#CD5C5C',        # Indian Red

    '#5C4033',        # Dark Brown

    '#2F4F4F',        # Dark Slate Gray

    '#8B4513',        # Saddle Brown

    '#4B0082',        # Indigo

    '#483D8B',        # Dark Slate Blue

    '#2C2C2C',        # Very Dark Gray

    '#3B3B3B'         # Dark Gray

]

# %%
W = 5.8

fig, ax = plt.subplots(figsize=(W/2, W/2))

ax.plot(date, flops, 'o', color=MyRed, mew = 2, lw = 1)
for i in range(len(date)):
    ax.text(date[i], flops[i], name[i], fontsize=6, ha='center', va='center')
ax.set_yscale('log')
ax.set_ylabel('FLOPS')
ax.set_xlabel('Year')
plt.savefig('../figures/supercomputer_flops.pdf', bbox_inches='tight', dpi = 600)
